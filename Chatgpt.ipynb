# %% [markdown]
# # ChatGPT Kullanımı

# %% [markdown]
# ## ChatGPT nedir?

# %% [markdown]
# ChatGPT, OpenAI tarafından geliştirilmiş bir chatbot dil modelidir . Konuşma dili üretimi için özel olarak tasarlanmış GPT-3 dil modelinin bir çeşididir.

# %% [markdown]
# ## ChatGPT python ile kullanımı

# %% [markdown]
# İlk olarak Open Ai üye olmak gerekmektedir.

# %% [markdown]
# ![kay%C4%B1t.png](attachment:kay%C4%B1t.png)

# %% [markdown]
# ## API Anahtarı Oluştur
# Kaydolduktan ve oturum açtıktan sonra, ChatGPT, DALL-E, API seçeneklerinden API'yı seçerek bir API anahtarı oluşturabilirsiniz:

# %% [markdown]
# ![API.png](attachment:API.png)

# %% [markdown]
# Sonrasında "QuickStart Tutorial" seçeneğini seçerek "Create New Secret Key" tıklayarak yeni Apı Keyimizi oluşturuyoruz.

# %% [markdown]
# ![secretap%C4%B1.png](attachment:secretap%C4%B1.png)

# %% [markdown]
# #### Artık bir proje oluşturmaya başlayabiliriz. İlk olarak bir python ChatGPT projesi oluşturalım.

# %% [markdown]
# OpenAPI Python İstemci Kitaplığını Kurun
# OpenAI Python kitaplığı, Python dilinde yazılmış uygulamalardan OpenAI API'ye kolay erişim sağlar. Kendilerini API yanıtlarından dinamik olarak başlatan, API kaynakları için önceden tanımlanmış bir dizi sınıf içerir ve bu da onu OpenAI API'nin çok çeşitli sürümleriyle uyumlu hale getirir.
#
# Bu kitaplık hakkında ayrıntılı bilgi için şu adrese gidin: https://github.com/openai/openai-python
#
# ### openai'yi yükleyin
# Gereksinimler
#
# ##### Python 3.7.1+
# ##### Openai 0.27.0+

# %%
# !pip install openai

# %% [markdown]
# ### ChatGPT Model

# %%
import openai

openai.api_key = "your-api-key"


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a chatbot"},
            {"role": "user", "content": "Merak ettiğim şeyi sorduğum yer"},
        ]
)

result = ''
for choice in response.choices:
    result += choice.message.content

print(result)

# %% [markdown]
# ### Text Davinci 0003 modeli

# %%
import openai

# Define OpenAI API key 
openai.api_key = "YOUR_API_KEY"

# Set up the model and prompt
model_engine = "text-davinci-003"
prompt = "HİKAYENİ YAZ VE GERİSİNİ DEVAM ETTİRSİN"

# Generate a response
completion = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

response = completion.choices[0].text
print(response)
